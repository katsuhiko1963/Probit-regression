# %%
# !pip install statsmodels
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import probit
import os

# Check if the file exists and remove it
if os.path.isfile('Probit Example.csv'):
    os.remove('Probit Example.csv')

# Now upload your file
from google.colab import files
uploaded = files.upload()

import io
df = pd.read_csv(io.BytesIO(uploaded['Probit example.csv']))
print(df.head())

# Define the formula (dependent variable ~ independent variables)
formula = 'inlf ~ kidslt6 + kidsge6 + age + educ + huswage + motheduc + fatheduc + unem + city'

# Fit the probit model
probit_model = probit(formula, data=df).fit()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      <input type="file" id="files-f3cbf252-9b29-47ec-8a3d-8a3a65c3dcfd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3cbf252-9b29-47ec-8a3d-8a3a65c3dcfd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
print(logit_model.summary())
# Out:
#                           Probit Regression Results
# ...
# Dep. Variable:                   inlf   No. Observations:                  753
# Model:                         Probit   Df Residuals:                      743
# Method:                           MLE   Df Model:                            9
# Date:                Sat, 20 May 2023   Pseudo R-squ.:                  0.1088
# Time:                        06:49:01   Log-Likelihood:                -458.88
# converged:                       True   LL-Null:                       -514.87
# Covariance Type:            nonrobust   LLR p-value:                 5.766e-20
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6453      0.485      1.331      0.183      -0.305       1.596
# kidslt6       -0.8888      0.113     -7.832      0.000      -1.111      -0.666
# ...

# %%
# Get the marginal effects
marginal_effects = probit_model.get_margeff()

# Print the marginal effects
print(marginal_effects.summary())
# Out:
#        Probit Marginal Effects
# ...
# Dep. Variable:                   inlf
# Method:                          dydx
# At:                           overall
# ...
#                 dy/dx    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# kidslt6       -0.3088      0.035     -8.942      0.000      -0.376      -0.241
# kidsge6       -0.0189      0.014     -1.357      0.175      -0.046       0.008
# age           -0.0130      0.003     -5.092      0.000      -0.018      -0.008
# educ           0.0521      0.008      6.152      0.000       0.035       0.069
# huswage       -0.0143      0.004     -3.215      0.001      -0.023      -0.006
# motheduc       0.0007      0.006      0.113      0.910      -0.012       0.013
# fatheduc      -0.0039      0.006     -0.655      0.512      -0.016       0.008
# unem          -0.0021      0.006     -0.375      0.708      -0.013       0.009
# ...
